# %%
from examples import detect_anomalies_in_mnist

detect_anomalies_in_mnist(9)
# Out:
# Dataset: mnist
# Interest class: 9

# %%
detect_anomalies_in_mnist(8)
# Out:
# Dataset: mnist
# Interest class: 8

# %%
detect_anomalies_in_mnist(7)
# Out:
# Dataset: mnist
# Interest class: 7
