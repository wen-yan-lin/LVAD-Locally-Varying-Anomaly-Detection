# %%
from examples import detect_anomalies_in_mnist

detect_anomalies_in_mnist(9)
# Out:
# Dataset: mnist
# Interest class: 9

# %%
detect_anomalies_in_mnist(1)
# Out:
# Dataset: mnist
# Interest class: 0
