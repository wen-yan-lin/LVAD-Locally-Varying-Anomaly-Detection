# %%
import numpy as np
from dataLoader import importData
from eval_norm_vs_denoise import pca_transform
import  matplotlib.pyplot as plt

title_font = {'family' : 'DejaVu Sans',
        'weight' : 'bold',
        'size'   : 12}

tic_font = {'family' : 'DejaVu Sans',
        'weight' : 'bold',
        'size'   : 10}

plt.rc('font', **tic_font)

# %%
x_train, y_train, x_test, y_test, dataset_name = importData(1)
est = np.mean(x_train[y_train==0])


feat = np.squeeze(np.load('../Flickr11K/resNet50.npy'))
true_mean = np.mean(feat, axis=0)

plt.hist(true_mean, range=[0, 3], bins=100);
plt.ylabel('Frequency')
plt.xlabel('Value')
plt.axvline(x=est, color='r', linestyle='--')
plt.legend(['estimated value of mean entries', 'true value of mean entries'])
# Out:
# Data-set: STL-10

# %%
x_train, y_train, x_test, y_test, dataset_name = importData(5)
x_train = x_train - np.min(x_train)
est = np.mean(x_train[y_train==0])
true_mean = np.mean(x_train, axis=0)

plt.hist(true_mean,  bins=100,  range=[10, 150],);
plt.ylabel('Frequency')
plt.xlabel('Value')
plt.axvline(x=est, color='r', linestyle='--')
plt.legend(['estimated value of mean entries', 'true value of mean entries'])
# Out:
# Data-set: mnist
