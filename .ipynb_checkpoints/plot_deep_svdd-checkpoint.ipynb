# %%
import matplotlib.pyplot as plt
import numpy

# %%
x = ['STL10', 'InterNet\n-STL10', 'MIT\n-Places', 'CIFAR-10', 'Cats\nvs Dogs']
y1 = [0.545, 0.511, 0.532, 0.491, 0.495]
y2 = [0.715, 0.689, 0.536, 0.606, 0.507]
y3 = [0.979, 0.996, 0.922, 0.903, 0.927]

# %%
title_font = {'family' : 'DejaVu Sans',
        'weight' : 'bold',
        'size'   : 12}

tic_font = {'family' : 'DejaVu Sans',
        'weight' : 'bold',
        'size'   : 10}

plt.rc('font', **tic_font)

# %%
plt.figure(figsize=(5, 7))

plt.plot(x, y3, 'k-', label = 'LVAD-ResNet-50', linewidth=2.5)
plt.plot(x, y2, 'k--', label = 'LVAD-Autoencoder', linewidth=2.5)
plt.plot(x, y1, 'k:', label = 'Deep-SVDD', linewidth=2.5)
#plt.xlabel('Dataset')
plt.ylabel('AUROC', fontsize=14.0)
#plt.rcParams["font.weight"] = "bold"

#plt.tick_params(axis='x', which='major', labelsize=9.7)
#plt.set_yticklabels(plt.get_yticks(), weight='bold')

plt.title('')
plt.legend(loc = 'center right')
plt.tight_layout()
plt.savefig('../rebuttal/ECCV 2022 LaTeX Guidelines for Author Response svdd_compare.pdf', bbox_inches='tight')
plt.show()
